# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Desktop//netflix_titles.csv")

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# # cleaning data

# %%
print("Count of Duplicated rows is :",df.duplicated().sum())
# Out:
# Count of Duplicated rows is : 0

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df = df.drop(['show_id'],axis=1)

# %%
df['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df.replace({'type':{'Movie':0,'TV Show':1}}, inplace=True)

# %%
df['title'].value_counts()
# Out:
# Dick Johnson Is Dead                     1
# Ip Man 2                                 1
# Hannibal Buress: Comedy Camisado         1
# Turbo FAST                               1
# Masha's Tales                            1
#                                         ..
# Love for Sale 2                          1
# ROAD TO ROMA                             1
# Good Time                                1
# Captain Underpants Epic Choice-o-Rama    1
# Zubaan                                   1
# Name: title, Length: 8807, dtype: int64

# %%
df = df.drop(columns=['title','director','cast'], axis=1)

# %%
df
# Out:
#       type        country          date_added  release_year rating   duration  \
# 0        0  United States  September 25, 2021          2020  PG-13     90 min
# 1        1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2        1            NaN  September 24, 2021          2021  TV-MA   1 Season
# 3        1            NaN  September 24, 2021          2021  TV-MA   1 Season
# 4        1          India  September 24, 2021          2021  TV-MA  2 Seasons
# ...    ...            ...                 ...           ...    ...        ...
# 8802     0  United States   November 20, 2019          2007      R    158 min
# 8803     1            NaN        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804     0  United States    November 1, 2019          2009      R     88 min
# 8805     0  United States    January 11, 2020          2006     PG     88 min
# 8806     0          India       March 2, 2019          2015  TV-14    111 min
#
# ...

# %%
df['country'] = df['country'].replace(np.nan, "Unknown")

# %%
df.isnull().sum()
# Out:
# type             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df.dropna(subset=['rating','duration','date_added'], inplace=True)

# %%
df.isnull().sum()
# Out:
# type            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df[ 'date_added']= df['date_added'].apply(pd.to_datetime)
df[ 'date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['loading_Year'] = df ['date_added'].dt.year
df['loading_Year']
# Out:
# 0       2021
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2019
# 8803    2019
# 8804    2019
# 8805    2020
# 8806    2019
# Name: loading_Year, Length: 8790, dtype: int64

# %%
df['loading_Month']= df ['date_added'].dt.month_name()
df['loading_Month']
# Out:
# 0       September
# 1       September
# 2       September
# 3       September
# 4       September
#           ...
# 8802     November
# 8803         July
# 8804     November
# 8805      January
# 8806        March
# Name: loading_Month, Length: 8790, dtype: object

# %%
df.drop("date_added",axis=1,inplace=True)

# %%
df
# Out:
#       type        country  release_year rating   duration  \
# 0        0  United States          2020  PG-13     90 min
# 1        1   South Africa          2021  TV-MA  2 Seasons
# 2        1        Unknown          2021  TV-MA   1 Season
# 3        1        Unknown          2021  TV-MA   1 Season
# 4        1          India          2021  TV-MA  2 Seasons
# ...    ...            ...           ...    ...        ...
# 8802     0  United States          2007      R    158 min
# 8803     1        Unknown          2018  TV-Y7  2 Seasons
# 8804     0  United States          2009      R     88 min
# 8805     0  United States          2006     PG     88 min
# 8806     0          India          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df['loading_Month'].value_counts()
# Out:
# July         827
# December     812
# September    769
# April        763
# October      760
# August       754
# March        741
# January      737
# June         728
# November     705
# May          632
# February     562
# Name: loading_Month, dtype: int64

# %%
df.replace({'loading_Month':{'January':1,
                             'February':2,
                             'March':3,
                             'April':4,
                             'May':5,
                             'June':6,
                             'July':7,
                             'August':8,
                             'September':9,
                             'October':10,
                             'November':11,
                             'December':12}}, inplace=True)

# %%
df['loading_Month'].dtype
# Out:
# dtype('int64')

# %%
df['loading_Year'].astype(int)
# Out:
# 0       2021
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2019
# 8803    2019
# 8804    2019
# 8805    2020
# 8806    2019
# Name: loading_Year, Length: 8790, dtype: int32

# %%
df[['Minutes_duration','Units_duration']] = df['duration'].str.split(' ',expand=True)

# %%
df['Minutes_duration'].astype(int)
# Out:
# 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: Minutes_duration, Length: 8790, dtype: int32

# %%
df['Units_duration'].value_counts()
# Out:
# min        6126
# Season     1791
# Seasons     873
# Name: Units_duration, dtype: int64

# %%
df.replace({'Units_duration':{'min':0,'Season':1, 'Seasons':2}}, inplace=True)

# %%
df.head(10)
# Out:
#    type                                            country  release_year  \
# 0     0                                      United States          2020
# 1     1                                       South Africa          2021
# 2     1                                            Unknown          2021
# 3     1                                            Unknown          2021
# 4     1                                              India          2021
# 5     1                                            Unknown          2021
# 6     0                                            Unknown          2021
# 7     0  United States, Ghana, Burkina Faso, United Kin...          1993
# 8     1                                     United Kingdom          2021
# 9     0                                      United States          2021
#
#   rating   duration                                          listed_in  \
# 0  PG-13     90 min                                      Documentaries
# ...

# %%
df.drop(['duration'], axis=1)
# Out:
#       type        country  release_year rating  \
# 0        0  United States          2020  PG-13
# 1        1   South Africa          2021  TV-MA
# 2        1        Unknown          2021  TV-MA
# 3        1        Unknown          2021  TV-MA
# 4        1          India          2021  TV-MA
# ...    ...            ...           ...    ...
# 8802     0  United States          2007      R
# 8803     1        Unknown          2018  TV-Y7
# 8804     0  United States          2009      R
# 8805     0  United States          2006     PG
# 8806     0          India          2015  TV-14
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df['release_year'].astype(int)
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2007
# 8803    2018
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 8790, dtype: int32

# %%
df['rating'].value_counts()
# Out:
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %%
df.replace({'rating':{'TV-MA':1,
                             'TV-14':2,
                             'TV-PG':3,
                             'R':4,
                             'PG-13':5,
                             'TV-Y7':6,
                             'TV-Y':7,
                             'PG':8,
                             'TV-G':9,
                             'NR':10,
                             'G':11,
                             'TV-Y7-FV':12,
                             'NC-17':13,
                            'UR':14}}, inplace=True)

# %%
df.head(3)
# Out:
#    type        country  release_year  rating   duration  \
# 0     0  United States          2020       5     90 min
# 1     1   South Africa          2021       1  2 Seasons
# 2     1        Unknown          2021       1   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  loading_Year  \
# 0  As her father nears the end of his life, filmm...          2021
# 1  After crossing paths at a party, a Cape Town t...          2021
# 2  To protect his family from a powerful drug lor...          2021
#
#    loading_Month Minutes_duration  Units_duration
# 0              9               90               0
# 1              9                2               2
# 2              9                1               1

# %%
# df.drop(['duration'], axis=1)

# %%
df['country'].value_counts()
# Out:
# United States                             2809
# India                                      972
# Unknown                                    829
# United Kingdom                             418
# Japan                                      243
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 749, dtype: int64

# %%
df['country'].unique()
# Out:
# array(['United States', 'South Africa', 'Unknown', 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

lab_encoder = LabelEncoder()

df['country'] = lab_encoder.fit_transform(df['country'])

# %%
df['listed_in'] = lab_encoder.fit_transform(df['listed_in'])

# %%
df.head()
# Out:
#    type  country  release_year  rating   duration  listed_in  \
# 0     0      603          2020       5     90 min        273
# 1     1      426          2021       1  2 Seasons        413
# 2     1      736          2021       1   1 Season        241
# 3     1      736          2021       1   1 Season        296
# 4     1      251          2021       1  2 Seasons        392
#
#                                          description  loading_Year  \
# 0  As her father nears the end of his life, filmm...          2021
# 1  After crossing paths at a party, a Cape Town t...          2021
# 2  To protect his family from a powerful drug lor...          2021
# 3  Feuds, flirtations and toilet talk go down amo...          2021
# 4  In a city of coaching centers known to train I...          2021
#
#    loading_Month Minutes_duration  Units_duration
# 0              9               90               0
# 1              9                2               2
# ...

# %%
df = df.drop(['description', 'duration'], axis=1)

# %%
df['Minutes_duration'] = df['Minutes_duration'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8790 entries, 0 to 8806
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              8790 non-null   int64
#  1   country           8790 non-null   int32
#  2   release_year      8790 non-null   int64
#  3   rating            8790 non-null   int64
#  4   listed_in         8790 non-null   int32
#  5   loading_Year      8790 non-null   int64
#  6   loading_Month     8790 non-null   int64
#  7   Minutes_duration  8790 non-null   int32
#  8   Units_duration    8790 non-null   int64
# dtypes: int32(3), int64(6)
# memory usage: 583.7 KB

# %% [markdown]
# # visualization data

# %%
# df.plot.bar()

# %%
sns.barplot(x= 'release_year', y='country', hue='type', data=df, orient='h')
# Out:
# <Axes: xlabel='release_year', ylabel='country'>

# %%
sns.barplot(x= 'Units_duration', y='loading_Month', hue='type', data=df, orient='h')
# Out:
# <Axes: xlabel='Units_duration', ylabel='loading_Month'>

# %%
# value = np.concatenate(['release_year', 'loading_Year']))
sns.distplot(df, bins=100, color='k')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3212\3844752804.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df, bins=100, color='k')
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df, diag_kind='kde', plot_kws={'alpha':0.2})

# %% [markdown]
# # splitting data

# %%
from sklearn.model_selection import train_test_split

x = df.drop(['Units_duration'], axis=1)
y = df['Units_duration']

x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.2, random_state=42)

# %%
x_train_2 = df.loc[:8000, :]

# %% [markdown]
# # apply model kmeans

# %%
from sklearn.cluster import KMeans

Model_Kmeans = KMeans(n_clusters=5, init='k-means++', random_state=33, algorithm='auto')

Model_Kmeans.fit(x_train_2)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1366: FutureWarning: algorithm='auto' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# KMeans(algorithm='auto', n_clusters=5, random_state=33)

# %% [markdown]
# # done
