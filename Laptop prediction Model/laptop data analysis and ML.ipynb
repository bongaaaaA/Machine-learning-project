# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('C:\\Users\\ALSHELSS\\OneDrive\\Desktop\\Machine-learning-project\\datasets\\laptop_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
data.shape
# Out:
# (1303, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# ###remove columns index

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
data['Ram'] = data['Ram'].str.replace('GB', '').astype('int32')

# %%
data['Weight'] = data['Weight'].str.replace('kg', '').astype('float32')

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\ALSHELSS\AppData\Local\Temp\ipykernel_17624\4196895882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
ScreenResolution = data['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
ScreenResolution
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
data['X_ScreenResolution'] = ScreenResolution[0]
data['Y_ScreenResolution'] = ScreenResolution[1]

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080
#
#               X_ScreenResolution Y_ScreenResolution
# 0  IPS Panel Retina Display 2560               1600
# 1                           1440                900
# 2                   Full HD 1920               1080
# 3  IPS Panel Retina Display 2880               1800
# 4  IPS Panel Retina Display 2560               1600

# %%
data['X_ScreenResolution'] = data['X_ScreenResolution'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0]).astype('int32')

# %%
data['Y_ScreenResolution'] = data['Y_ScreenResolution'].astype('int32')

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080
#
#    X_ScreenResolution  Y_ScreenResolution
# 0                2560                1600
# 1                1440                 900
# 2                1920                1080
# 3                2880                1800
# 4                2560                1600

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company             1303 non-null   object
#  1   TypeName            1303 non-null   object
#  2   Inches              1303 non-null   float64
#  3   ScreenResolution    1303 non-null   object
#  4   Cpu                 1303 non-null   object
#  5   Ram                 1303 non-null   int32
#  6   Memory              1303 non-null   object
#  7   Gpu                 1303 non-null   object
#  8   OpSys               1303 non-null   object
#  9   Weight              1303 non-null   float32
#  10  Price               1303 non-null   float64
#  11  X_ScreenResolution  1303 non-null   int32
#  12  Y_ScreenResolution  1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), object(7)
# memory usage: 112.1+ KB

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
data['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
data['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
data['Company'] = encoder.fit_transform(data['Company'])

data['TypeName'] = encoder.fit_transform(data['TypeName'])

data['OpSys'] = encoder.fit_transform(data['OpSys'])

# %%
data.head()
# Out:
#    Company  TypeName  Inches                    ScreenResolution  \
# 0        1         4    13.3  IPS Panel Retina Display 2560x1600
# 1        1         4    13.3                            1440x900
# 2        7         3    15.6                   Full HD 1920x1080
# 3        1         4    15.4  IPS Panel Retina Display 2880x1800
# 4        1         4    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640      8    1.37   71378.6832
# 1        Intel HD Graphics 6000      8    1.34   47895.5232
# 2         Intel HD Graphics 620      4    1.86   30636.0000
# 3            AMD Radeon Pro 455      8    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650      8    1.37   96095.8080
#
#    X_ScreenResolution  Y_ScreenResolution
# 0                2560                1600
# 1                1440                 900
# 2                1920                1080
# 3                2880                1800
# 4                2560                1600

# %%
data['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
data['Cpu name'] = data['Cpu'].apply(lambda x : " ".join(x.split()[0:3]))

# %%
data.head()
# Out:
#    Company  TypeName  Inches                    ScreenResolution  \
# 0        1         4    13.3  IPS Panel Retina Display 2560x1600
# 1        1         4    13.3                            1440x900
# 2        7         3    15.6                   Full HD 1920x1080
# 3        1         4    15.4  IPS Panel Retina Display 2880x1800
# 4        1         4    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640      8    1.37   71378.6832
# 1        Intel HD Graphics 6000      8    1.34   47895.5232
# 2         Intel HD Graphics 620      4    1.86   30636.0000
# 3            AMD Radeon Pro 455      8    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650      8    1.37   96095.8080
#
#    X_ScreenResolution  Y_ScreenResolution       Cpu name
# 0                2560                1600  Intel Core i5
# 1                1440                 900  Intel Core i5
# 2                1920                1080  Intel Core i5
# 3                2880                1800  Intel Core i7
# 4                2560                1600  Intel Core i5

# %%
data['Cpu name'].value_counts()
# Out:
# Cpu name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# AMD FX 9830P                  1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom Z8350              1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000e            1
# Samsung Cortex A72&A53        1
# AMD E-Series 9000             1
# AMD E-Series 6110             1
# Name: count, dtype: int64

# %%
def processind_cpu(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3' :
        return text
    else:
        if text.split()[0] == "Intel":
            return "intel processor"
        else:
            return "Amd precosser"

# %%
data['Cpu brand'] = data['Cpu name'].apply(processind_cpu)

# %%
data['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
data['Cpu brand'] = encoder.fit_transform(data['Cpu brand'])

# %%
data.head()
# Out:
#    Company  TypeName  Inches                    ScreenResolution  \
# 0        1         4    13.3  IPS Panel Retina Display 2560x1600
# 1        1         4    13.3                            1440x900
# 2        7         3    15.6                   Full HD 1920x1080
# 3        1         4    15.4  IPS Panel Retina Display 2880x1800
# 4        1         4    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640      8    1.37   71378.6832
# 1        Intel HD Graphics 6000      8    1.34   47895.5232
# 2         Intel HD Graphics 620      4    1.86   30636.0000
# 3            AMD Radeon Pro 455      8    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650      8    1.37   96095.8080
#
#    X_ScreenResolution  Y_ScreenResolution       Cpu name  Cpu brand
# 0                2560                1600  Intel Core i5          2
# 1                1440                 900  Intel Core i5          2
# 2                1920                1080  Intel Core i5          2
# 3                2880                1800  Intel Core i7          3
# 4                2560                1600  Intel Core i5          2

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
data['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='Gpu', data=data)
# Out:
# <Axes: xlabel='Gpu', ylabel='count'>

# %%
data['Gpu name'] = data['Gpu'].apply(lambda x : " ".join(x.split()[0:3]))

# %%
data.head(10)
# Out:
#    Company  TypeName  Inches                    ScreenResolution  \
# 0        1         4    13.3  IPS Panel Retina Display 2560x1600
# 1        1         4    13.3                            1440x900
# 2        7         3    15.6                   Full HD 1920x1080
# 3        1         4    15.4  IPS Panel Retina Display 2880x1800
# 4        1         4    13.3  IPS Panel Retina Display 2560x1600
# 5        0         3    15.6                            1366x768
# 6        1         4    15.4  IPS Panel Retina Display 2880x1800
# 7        1         4    13.3                            1440x900
# 8        2         4    14.0                   Full HD 1920x1080
# 9        0         4    14.0         IPS Panel Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
# 5     AMD A9-Series 9420 3GHz    4            500GB HDD
# 6        Intel Core i7 2.2GHz   16  256GB Flash Storage
# 7        Intel Core i5 1.8GHz    8  256GB Flash Storage
# 8  Intel Core i7 8550U 1.8GHz   16            512GB SSD
# 9  Intel Core i5 8250U 1.6GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640      8    1.37   71378.6832
# 1        Intel HD Graphics 6000      8    1.34   47895.5232
# 2         Intel HD Graphics 620      4    1.86   30636.0000
# 3            AMD Radeon Pro 455      8    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650      8    1.37   96095.8080
# 5                 AMD Radeon R5      5    2.10   21312.0000
# 6       Intel Iris Pro Graphics      3    2.04  114017.6016
# 7        Intel HD Graphics 6000      8    1.34   61735.5360
# 8          Nvidia GeForce MX150      5    1.30   79653.6000
# 9        Intel UHD Graphics 620      5    1.60   41025.6000
#
#    X_ScreenResolution  Y_ScreenResolution            Cpu name  Cpu brand  \
# 0                2560                1600       Intel Core i5          2
# 1                1440                 900       Intel Core i5          2
# 2                1920                1080       Intel Core i5          2
# 3                2880                1800       Intel Core i7          3
# 4                2560                1600       Intel Core i5          2
# 5                1366                 768  AMD A9-Series 9420          0
# 6                2880                1800       Intel Core i7          3
# 7                1440                 900       Intel Core i5          2
# 8                1920                1080       Intel Core i7          3
# 9                1920                1080       Intel Core i5          2
#
#                Gpu name
# 0       Intel Iris Plus
# 1     Intel HD Graphics
# 2     Intel HD Graphics
# 3        AMD Radeon Pro
# 4       Intel Iris Plus
# 5         AMD Radeon R5
# 6        Intel Iris Pro
# 7     Intel HD Graphics
# 8  Nvidia GeForce MX150
# 9    Intel UHD Graphics

# %%
data['Gpu name'].value_counts()
# Out:
# Gpu name
# Intel HD Graphics         639
# Nvidia GeForce GTX        235
# Intel UHD Graphics         68
# AMD Radeon R5              54
# Nvidia GeForce 940MX       43
# AMD Radeon 530             41
# AMD Radeon R7              26
# Nvidia GeForce 930MX       25
# Nvidia GeForce 920MX       18
# AMD Radeon 520             17
# Nvidia GeForce MX150       15
# AMD Radeon RX              12
# Intel Iris Plus            10
# AMD Radeon R2               9
# Nvidia Quadro M1200         9
# AMD Radeon R4               8
# Nvidia GeForce MX130        6
# Nvidia GeForce 930M         6
# Nvidia GeForce 920M         6
# Nvidia Quadro M620          5
# Nvidia GeForce GT           5
# Nvidia Quadro M1000M        4
# Nvidia Quadro M2200M        3
# AMD FirePro W4190M          3
# Intel Iris Graphics         3
# Nvidia GeForce 150MX        3
# AMD Radeon Pro              3
# Nvidia Quadro M2000M        2
# Nvidia Quadro M520M         2
# Nvidia Quadro M2200         2
# Nvidia GeForce GTX1060      1
# Nvidia GeForce 960M         1
# Nvidia Quadro M3000M        1
# Nvidia Quadro M500M         1
# AMD FirePro W6150M          1
# Nvidia Quadro 3000M         1
# AMD Radeon R9               1
# AMD Radeon R3               1
# Nvidia GeForce 940M         1
# Nvidia GeForce 920          1
# AMD R17M-M1-70              1
# AMD Radeon 540              1
# Nvidia GTX 980              1
# Intel Graphics 620          1
# Nvidia Quadro M620M         1
# Nvidia GeForce GTX1050      1
# Nvidia GeForce GTX1080      1
# Intel Iris Pro              1
# AMD FirePro W5130M          1
# AMD R4 Graphics             1
# ARM Mali T860               1
# Name: count, dtype: int64

# %%
def processind_Gpu(text):
    if text.split()[0] == "Nvidia":
        return "Nvidia processor"
    elif text.split()[0] == "Intel":
        return "intel processor"
    else:
        return "Amd precosser"

# %%
data['Gpu brand'] = data['Gpu name'].apply(processind_Gpu)

# %%
data['Gpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu brand'>

# %%
data['Gpu brand'] = encoder.fit_transform(data['Gpu brand'])

# %%
data.head(10)
# Out:
#    Company  TypeName  Inches                    ScreenResolution  \
# 0        1         4    13.3  IPS Panel Retina Display 2560x1600
# 1        1         4    13.3                            1440x900
# 2        7         3    15.6                   Full HD 1920x1080
# 3        1         4    15.4  IPS Panel Retina Display 2880x1800
# 4        1         4    13.3  IPS Panel Retina Display 2560x1600
# 5        0         3    15.6                            1366x768
# 6        1         4    15.4  IPS Panel Retina Display 2880x1800
# 7        1         4    13.3                            1440x900
# 8        2         4    14.0                   Full HD 1920x1080
# 9        0         4    14.0         IPS Panel Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
# 5     AMD A9-Series 9420 3GHz    4            500GB HDD
# 6        Intel Core i7 2.2GHz   16  256GB Flash Storage
# 7        Intel Core i5 1.8GHz    8  256GB Flash Storage
# 8  Intel Core i7 8550U 1.8GHz   16            512GB SSD
# 9  Intel Core i5 8250U 1.6GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640      8    1.37   71378.6832
# 1        Intel HD Graphics 6000      8    1.34   47895.5232
# 2         Intel HD Graphics 620      4    1.86   30636.0000
# 3            AMD Radeon Pro 455      8    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650      8    1.37   96095.8080
# 5                 AMD Radeon R5      5    2.10   21312.0000
# 6       Intel Iris Pro Graphics      3    2.04  114017.6016
# 7        Intel HD Graphics 6000      8    1.34   61735.5360
# 8          Nvidia GeForce MX150      5    1.30   79653.6000
# 9        Intel UHD Graphics 620      5    1.60   41025.6000
#
#    X_ScreenResolution  Y_ScreenResolution            Cpu name  Cpu brand  \
# 0                2560                1600       Intel Core i5          2
# 1                1440                 900       Intel Core i5          2
# 2                1920                1080       Intel Core i5          2
# 3                2880                1800       Intel Core i7          3
# 4                2560                1600       Intel Core i5          2
# 5                1366                 768  AMD A9-Series 9420          0
# 6                2880                1800       Intel Core i7          3
# 7                1440                 900       Intel Core i5          2
# 8                1920                1080       Intel Core i7          3
# 9                1920                1080       Intel Core i5          2
#
#                Gpu name  Gpu brand
# 0       Intel Iris Plus          2
# 1     Intel HD Graphics          2
# 2     Intel HD Graphics          2
# 3        AMD Radeon Pro          0
# 4       Intel Iris Plus          2
# 5         AMD Radeon R5          0
# 6        Intel Iris Pro          2
# 7     Intel HD Graphics          2
# 8  Nvidia GeForce MX150          1
# 9    Intel UHD Graphics          2

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
Memory = data['Memory'].str.split(' ',n=1,expand=True)

# %%
Memory
# Out:
#           0              1
# 0     128GB            SSD
# 1     128GB  Flash Storage
# 2     256GB            SSD
# 3     512GB            SSD
# 4     256GB            SSD
# ...     ...            ...
# 1298  128GB            SSD
# 1299  512GB            SSD
# 1300   64GB  Flash Storage
# 1301    1TB            HDD
# 1302  500GB            HDD
#
# [1303 rows x 2 columns]

# %%
data['Memory size'] = Memory[0]

# %%
data.sample(10)
# Out:
#       Company  TypeName  Inches                 ScreenResolution  \
# 1012        7         3    14.0                Full HD 1920x1080
# 49          2         3    17.3                         1366x768
# 696        10         0    14.0  Full HD / Touchscreen 1920x1080
# 172        10         3    15.6                         1366x768
# 843         4         3    15.6                         1366x768
# 800         7         5    15.6                Full HD 1920x1080
# 334         2         1    15.6                Full HD 1920x1080
# 1037       16         4    14.0      IPS Panel Full HD 1920x1080
# 53          7         3    13.3                Full HD 1920x1080
# 1158       10         3    15.6                Full HD 1920x1080
#
#                                        Cpu  Ram        Memory  \
# 1012            Intel Core i5 7200U 2.5GHz    4     256GB SSD
# 49    Intel Pentium Quad Core N4200 1.1GHz    4       1TB HDD
# 696             Intel Core i7 7500U 2.7GHz   16     512GB SSD
# 172              AMD A6-Series 9220 2.9GHz    4     500GB HDD
# 843             Intel Core i5 7200U 2.5GHz    8     128GB SSD
# 800            Intel Core i7 7700HQ 2.8GHz    8     256GB SSD
# 334            Intel Core i7 7700HQ 2.8GHz    8     256GB SSD
# 1037            Intel Core i7 6600U 2.6GHz    8     256GB SSD
# 53              Intel Core i7 8550U 1.8GHz    8     512GB SSD
# 1158            Intel Core i5 6200U 2.3GHz    8  1.0TB Hybrid
#
#                           Gpu  OpSys  Weight        Price  X_ScreenResolution  \
# 1012    Intel HD Graphics 620      5    1.48   84715.2000                1920
# 49       Nvidia GeForce 920MX      5    2.80   24828.4800                1366
# 696     Intel HD Graphics 620      5    1.38   93186.7200                1920
# 172    AMD Radeon R4 Graphics      4    2.20   16463.5200                1366
# 843     Intel HD Graphics 620      5    2.18   38041.3872                1366
# 800       Nvidia Quadro M2200      5    3.14  110017.8720                1920
# 334   Nvidia GeForce GTX 1050      5    2.50   53226.7200                1920
# 1037    Intel HD Graphics 520      5    1.47   91908.0000                1920
# 53     Intel UHD Graphics 620      5    1.49   58767.8400                1920
# 1158       AMD Radeon R5 M330      5    2.50   42010.7472                1920
#
#       Y_ScreenResolution            Cpu name  Cpu brand              Gpu name  \
# 1012                1080       Intel Core i5          2     Intel HD Graphics
# 49                   768  Intel Pentium Quad          4  Nvidia GeForce 920MX
# 696                 1080       Intel Core i7          3     Intel HD Graphics
# 172                  768  AMD A6-Series 9220          0         AMD Radeon R4
# 843                  768       Intel Core i5          2     Intel HD Graphics
# 800                 1080       Intel Core i7          3   Nvidia Quadro M2200
# 334                 1080       Intel Core i7          3    Nvidia GeForce GTX
# 1037                1080       Intel Core i7          3     Intel HD Graphics
# 53                  1080       Intel Core i7          3    Intel UHD Graphics
# 1158                1080       Intel Core i5          2         AMD Radeon R5
#
#       Gpu brand Memory size
# 1012          2       256GB
# 49            1         1TB
# 696           2       512GB
# 172           0       500GB
# 843           2       128GB
# 800           1       256GB
# 334           1       256GB
# 1037          2       256GB
# 53            2       512GB
# 1158          0       1.0TB

# %%
data['Memory size'].value_counts()
# Out:
# Memory size
# 256GB    508
# 1TB      240
# 128GB    177
# 512GB    140
# 500GB    132
# 32GB      45
# 64GB      17
# 2TB       16
# 1.0TB     10
# 16GB      10
# 180GB      5
# 240GB      1
# 8GB        1
# 508GB      1
# Name: count, dtype: int64

# %%
data['Memory size'] = encoder.fit_transform(data['Memory size'])

# %%
data.head()
# Out:
#    Company  TypeName  Inches                    ScreenResolution  \
# 0        1         4    13.3  IPS Panel Retina Display 2560x1600
# 1        1         4    13.3                            1440x900
# 2        7         3    15.6                   Full HD 1920x1080
# 3        1         4    15.4  IPS Panel Retina Display 2880x1800
# 4        1         4    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  \
# 0  Intel Iris Plus Graphics 640      8    1.37   71378.6832
# 1        Intel HD Graphics 6000      8    1.34   47895.5232
# 2         Intel HD Graphics 620      4    1.86   30636.0000
# 3            AMD Radeon Pro 455      8    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650      8    1.37   96095.8080
#
#    X_ScreenResolution  Y_ScreenResolution       Cpu name  Cpu brand  \
# 0                2560                1600  Intel Core i5          2
# 1                1440                 900  Intel Core i5          2
# 2                1920                1080  Intel Core i5          2
# 3                2880                1800  Intel Core i7          3
# 4                2560                1600  Intel Core i5          2
#
#             Gpu name  Gpu brand  Memory size
# 0    Intel Iris Plus          2            1
# 1  Intel HD Graphics          2            1
# 2  Intel HD Graphics          2            6
# 3     AMD Radeon Pro          0           11
# 4    Intel Iris Plus          2            6

# %%
x  = data.drop(columns=['ScreenResolution','Cpu','Memory','Gpu','Cpu name','Gpu name','Price'])
y = data['Price']

# %% [markdown]
# #### phase models

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.score(x_train,y_train)*100)
# Out:
# 68.65091410528923

# %%
print(model.score(x_test,y_test)*100)
# Out:
# 59.02001400663941

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
def select_model(m):
    model = m()
    model.fit(x_train,y_train)
    print(model.score(x_train,y_train)*100)
    print(model.score(x_test,y_test)*100)

# %% [markdown]
# #### GradientBoostingRegressor model

# %%
select_model(GradientBoostingRegressor)
# Out:
# 88.91133101989941
# 80.83913236155958

# %% [markdown]
# Save Model

# %%
import joblib

joblib.dump(model, "laptop_price_model.pkl")
# Out:
# ['laptop_price_model.pkl']

# %% [markdown]
# #### KNeighborsRegressor  model

# %% [markdown]
# ### data graphs

# %%
data.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'X_ScreenResolution',
#        'Y_ScreenResolution', 'Cpu name', 'Cpu brand', 'Gpu name', 'Gpu brand',
#        'Memory size'],
#       dtype='object')

# %%
sns.countplot(x='Company',data=data)
# Out:
# <Axes: xlabel='Company', ylabel='count'>

# %%
sns.countplot(x='TypeName',data=data)
# Out:
# <Axes: xlabel='TypeName', ylabel='count'>

# %%
sns.countplot(x='Inches',data=data)
# Out:
# <Axes: xlabel='Inches', ylabel='count'>

# %%
sns.countplot(x='Cpu',data=data)
# Out:
# <Axes: xlabel='Cpu', ylabel='count'>

# %%
sns.countplot(x='Gpu',data=data)
# Out:
# <Axes: xlabel='Gpu', ylabel='count'>

# %%
sns.countplot(x='OpSys',data=data)
# Out:
# <Axes: xlabel='OpSys', ylabel='count'>

# %%
data['OpSys'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
data['Inches'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
data['TypeName'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
data['Company'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>
