# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/ALSHELSS/OneDrive/Desktop/Machine-learning-project/datasets/car data.csv")

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
print(f"number of rows and columns {data.shape}")
# Out:
# number of rows and columns (301, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
categorical_columns = ["Car_Name","Fuel_Type","Seller_Type","Transmission"]
for i in categorical_columns:
    print(f"value counts of {i}")
    print(data[i].value_counts())
    print("#"*40)
# Out:
# value counts of Car_Name
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64
# ########################################
# value counts of Fuel_Type
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
# ########################################
# value counts of Seller_Type
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64
# ########################################
# value counts of Transmission
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64
# ########################################

# %%
Transmission_counts = data["Transmission"].value_counts()

# %%
plt.figure()
plt.pie(
    Transmission_counts.values,
    labels=Transmission_counts.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Transmission_counts Type Distribution")

plt.show()

# %%
seller_counts = data["Seller_Type"].value_counts()

# %%
plt.figure()
plt.pie(
    seller_counts.values,
    labels=seller_counts.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Seller Type Distribution")

plt.show()

# %%
data.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
# Out:
# C:\Users\ALSHELSS\AppData\Local\Temp\ipykernel_22712\280158549.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# %%
data.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)
# Out:
# C:\Users\ALSHELSS\AppData\Local\Temp\ipykernel_22712\1550058087.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
data.replace({'Seller_Type':{'Dealer':0,'Individual':1}},inplace=True)
# Out:
# C:\Users\ALSHELSS\AppData\Local\Temp\ipykernel_22712\762156602.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'Seller_Type':{'Dealer':0,'Individual':1}},inplace=True)

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 3            0             0      0
# 4            0             0      0

# %%
x = data.drop(columns=['Car_Name','Present_Price'],axis=1)
y = data['Present_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
train_predict = model.predict(x_train)

# %%
score = metrics.r2_score(y_train,train_predict)
print("A squre error :", score)
# Out:
# A squre error : 0.8531109379561066

# %%
def train_model(model):
    model.fit(x_train,y_train)
    train_predict = model.predict(x_train)
    score = metrics.r2_score(y_train,train_predict)
    print("A squre error :", score)
    print(model.score(x_train,y_train)*100)
    print(model.score(x_test,y_test)*100)
    plt.scatter(y_train,train_predict)

# %%
train_model(model)
# Out:
# A squre error : 0.8531109379561066
# 85.31109379561066
# 78.84175427805417

# %% [markdown]
# Save Model

# %%
import joblib

joblib.dump(model, "car_price_model.pkl")
# Out:
# ['car_price_model.pkl']

# %% [markdown]
# done Model
